# %% [markdown]
# ## Подключение библиотек

# %%
import numpy as np
import pandas as pd

import seaborn as sns
sns.set_style("whitegrid")

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from matplotlib import rcParams
rcParams['figure.figsize'] = 10, 8
rcParams['font.size'] = 16
rcParams['axes.labelsize'] = 14
rcParams['xtick.labelsize'] = 13
rcParams['ytick.labelsize'] = 13
rcParams['legend.fontsize'] = 15

# %%
import matplotlib as mpl

# %%
from IPython.display import Image

# %% [markdown]
# # Функция `plot`

# %%
x = [1, 2, 3, 4]
y = np.array([1, 5, 6, 3])
plt.xlabel("Итерация")
plt.ylabel("Ошибка (%)")
plt.title("Best method")
plt.plot(x, y)

# %%
x = np.linspace(0, 2, 100)
plt.plot(x, x**2)
x = np.linspace(0, 4, 100)
plt.plot(x, np.sqrt(x))
plt.grid(True)
#plt.axis('equal')
plt.axis([-1, 5, 0, 6])
#plt.xlim(-1, 5)
#plt.ylim(0, 6)
# Out:
# (-1.0, 5.0, 0.0, 6.0)

# %%
x = np.linspace(-6, 6, 100)
plt.plot(x, np.sin(x), 'b', label = 'sin(x)')
plt.plot(x, np.cos(x), 'r', label = 'cos(x)')
#axis('equal')
plt.legend(loc = 'best', framealpha = 1)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Trigonometric functions')
pass

# %%
x = np.linspace(0, 1, 3)
plt.plot(x, x, '-', x, 2*x, '--', x, 3*x, ':', x, 4*x, '-.')
# Out:
# [<matplotlib.lines.Line2D at 0x7e84199b89d0>,
#  <matplotlib.lines.Line2D at 0x7e84199bbd60>,
#  <matplotlib.lines.Line2D at 0x7e84199bbc40>,
#  <matplotlib.lines.Line2D at 0x7e84199bbdc0>]

# %%
from cycler import cycler
# Change the default cycle colors to be red, green, blue, and yellow
plt.rc('axes', prop_cycle=(cycler('color', ['b', 'r', 'g'])))
x = np.linspace(0, 1, 3)
plt.plot(x, x, x, 2*x, x, 3*x, x, 4*x, x, 5*x, x, 6*x, x, 7*x, x, 8*x, x, 9*x, x, 10*x, x, 11*x)
# Out:
# [<matplotlib.lines.Line2D at 0x7e8418698d90>,
#  <matplotlib.lines.Line2D at 0x7e8418698d60>,
#  <matplotlib.lines.Line2D at 0x7e8418698c70>,
#  <matplotlib.lines.Line2D at 0x7e841869a8f0>,
#  <matplotlib.lines.Line2D at 0x7e841869a9e0>,
#  <matplotlib.lines.Line2D at 0x7e841869aad0>,
#  <matplotlib.lines.Line2D at 0x7e841869abc0>,
#  <matplotlib.lines.Line2D at 0x7e841869a860>,
#  <matplotlib.lines.Line2D at 0x7e841869acb0>,
#  <matplotlib.lines.Line2D at 0x7e841869a830>,
#  <matplotlib.lines.Line2D at 0x7e841869a680>]

# %%
x = np.array([0, 1, 2, 3, 4])
y = x**2
plt.plot(x, y, marker = '*', color = 'red', linewidth = 2, \
         markerfacecolor = 'yellow', markeredgecolor = 'blue', \
         markersize = 25)

# %%
x = np.linspace(0, 1, 11)
y = np.zeros(x.shape)
plt.plot(x, y,     '-')
plt.plot(x, y + 1, '.')
plt.plot(x, y + 2, 'o', markerfacecolor = 'red', markeredgecolor = 'red')
plt.plot(x, y + 3, '*')
plt.plot(x, y + 4, '^', markeredgecolor = 'magenta')
plt.plot(x, y + 5, 'v', markerfacecolor = 'yellow', markeredgecolor = 'yellow')
plt.plot(x, y + 6, 's', markersize = 4, markeredgecolor = 'blue')
plt.plot(x, y + 7, '+', markersize = 5)
plt.plot(x, y + 8, 'x', markersize = 15)
plt.text(.5, 4.5, 'Marker examples',
         horizontalalignment = 'center', verticalalignment = 'center',
         fontsize = 10, color = 'blue')
#plt.ylim([-1, 9])
# Out:
# Text(0.5, 4.5, 'Marker examples')

# %%
plt.figure()

# %%
plt.figure(figsize = (10, 8))
plt.plot(x, y,     '-')

# %%
plt.show()

# %% [markdown]
# ### Параметрические графики
# $$
# x = \sin t/t,
# \quad
# y = \cos t/t
# $$
# $x = \frac{\sin t}{t},\ y = \frac{\cos t}{t}$

# %%
t = np.linspace(1.5, 32, 200)
plt.axis('equal')
plt.title(r'$x = \frac{\sin t}{t},\ y = \frac{\cos t}{t}$')
x = np.sin(t)/t
y = np.cos(t)/t
plt.plot(x, y)

# %% [markdown]
# ## Чтение данных

# %%
from sklearn.datasets import fetch_california_housing

# %%
#Цены Магнит
prices = pd.read_csv('https://raw.githubusercontent.com/yakushinav/omo/main/data/Magnit.csv')
prices['date'] = pd.date_range('1/1/2023', periods=len(prices), freq='D')
share = pd.Series(prices.Magnit.ravel(), index=prices.date)

#Набор данных "Чаевые"
tips = sns.load_dataset('tips')

#Набор данных "Цены на недвижимость в Калифорнии"
bunch = fetch_california_housing()
df, y = pd.DataFrame(data=bunch.data, columns=bunch.feature_names), bunch.target
df['target'] = y
# Out:
# <ipython-input-23-69dcbc930bd0>:4: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   share = pd.Series(prices.Magnit.ravel(), index=prices.date)

# %% [markdown]
# # Данные изменяющиеся во времени

# %% [markdown]
# ## График (Line plot)

# %%
plt.plot(prices.Magnit);

# %% [markdown]
# __Когда использовать?__
#
# Когда нужно показать изменение показателя во времени

# %% [markdown]
# ## Гистограмма (Bar plot)

# %%
plt.bar(range(len(prices[1:220:30])), prices.Magnit[1:220:30]);

# %% [markdown]
# ## Гистограмма с областями (Area plot)

# %%
part = prices.Magnit[:11]
part.plot.area(ylim=[part.min() - 500, part.max() + 500]);

# %% [markdown]
# Хорошо показывает общий объем.

# %% [markdown]
# # Отклонения

# %% [markdown]
# ## Диаграмма с отклонениями (Bar plot)

# %%
some_prices = prices.Magnit[1:220:30]
some_prices -= some_prices.mean()
plt.bar(range(len(some_prices)), some_prices);

# %% [markdown]
# ## Диаграмма разброса (Spine chart)

# %%
a = np.sin(np.linspace(0, np.pi))
b = np.cos(np.linspace(0, np.pi)) + 1
ind = range(len(a))

plt.barh(ind, -a, label='Sine');
plt.barh(ind, b, color='#d62728', label='Cosine');
plt.legend();

# %% [markdown]
# # Корреляция

# %% [markdown]
# ## Поле корреляции (Scatterplot)

# %%
data = prices.Magnit[0:100]
data_lag = prices.Magnit[7:107]

plt.scatter(data_lag, data);

# %% [markdown]
# ## Connected scatterplot

# %%
data = prices.Magnit[0:100]
data_lag = prices.Magnit[7:107]

plt.scatter(data_lag, data);
plt.plot(data_lag, data);

# %% [markdown]
# ## Bubble plot

# %%
data = prices.Magnit[0:100]
data_lag = prices.Magnit[7:107]

sizes = np.random.randn(len(data))
sizes += np.abs(1.5*sizes.min())
sizes *= 70

plt.scatter(data_lag, data, s=sizes, alpha=0.4);

# %% [markdown]
# Like a scatterplot, but adds additional detail by sizing the circles according to a third variable

# %% [markdown]
# ## Тепловая карта (Heatmap)

# %%
sns.heatmap(tips.corr(numeric_only=True), annot=True, lw=1);

# %% [markdown]
# # Распределение

# %% [markdown]
# ## Гистограмма (Histogram)

# %%
prices.Magnit.hist();

# %% [markdown]
# ## Ящик с усами (Boxplot)

# %%
sns.boxplot(y='smoker', x='tip', orient='h', data=tips);

# %% [markdown]
# ## Cкрипичная диаграмма (Violin plot)

# %%
sns.violinplot(y='smoker', x='tip', orient='h', data=tips);

# %% [markdown]
# ## Роевая диаграмма (Swarm plot)

# %%
sns.swarmplot(y='smoker', x='tip', orient='h', data=tips);

# %% [markdown]
# ## Одномерная диаграмма рассеяния (Stripplot)

# %%
sns.stripplot(y='smoker', x='tip', orient='h', data=tips, jitter=True);

# %% [markdown]
# # Отношение "часть-целое"

# %% [markdown]
# ## Stacked normalized (percentage) bar plot

# %%
raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
        'pre_score': [4, 24, 31, 2, 3],
        'mid_score': [25, 94, 57, 62, 70],
        'post_score': [5, 43, 23, 23, 51]}
df = pd.DataFrame(raw_data, columns = ['first_name', 'pre_score', 'mid_score', 'post_score'])

f, ax = plt.subplots(1, figsize=(10,5))

bar_width = 1

bar_l = [i for i in range(len(df['pre_score']))]

tick_pos = [i+(bar_width/2) for i in bar_l]

totals = [i+j+k for i,j,k in zip(df['pre_score'], df['mid_score'], df['post_score'])]
pre_rel = [i / j * 100 for  i,j in zip(df['pre_score'], totals)]
mid_rel = [i / j * 100 for  i,j in zip(df['mid_score'], totals)]
post_rel = [i / j * 100 for  i,j in zip(df['post_score'], totals)]

ax.bar(bar_l, pre_rel,                  label='Pre Score', alpha=0.9, color='#019600', width=bar_width, edgecolor='white')
ax.bar(bar_l, mid_rel,  bottom=pre_rel, label='Mid Score', alpha=0.9, color='#3C5F5A', width=bar_width, edgecolor='white')
ax.bar(bar_l, post_rel, bottom=[i+j for i,j in zip(pre_rel, mid_rel)], label='Post Score',alpha=0.9,
       color='#219AD8', width=bar_width,edgecolor='white')

plt.xticks(tick_pos, df['first_name'])
ax.set_ylabel("Percentage")
ax.set_xlabel("")
ax.margins(0);

plt.show()

# %% [markdown]
# ## Круговая диаграмма (Pie chart)

# %%
tips.day = tips.day.astype('category')
f, ax = plt.subplots(1, figsize=(7,7))
tips.groupby('day').agg('sum', numeric_only=True)['tip'].plot.pie(ax=ax, shadow=True, startangle=90,
                                               colors=['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']);
# Out:
# <ipython-input-42-11c174edd5cf>:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips.groupby('day').agg('sum', numeric_only=True)['tip'].plot.pie(ax=ax, shadow=True, startangle=90,

# %%
# Более сложное рисование, например, с несколькими графиками
f, axs = plt.subplots(1,3, figsize=(20, 5))
prices.Magnit.plot(ax=axs[0]);
prices.Magnit.hist(bins=20, ax=axs[1]);
prices.Magnit.plot.kde(ax=axs[2]);

# %% [markdown]
# ## Дополнительные возможности Seaborn

# %%
sns.set()

# %%
# Диаграмма рассеяния
sns.lmplot(x='total_bill', y='tip', data=tips);

# %%
# Плотность распределения
sns.displot(tips.total_bill, bins=20);

# %%
# Карта распределения по признакам
g = sns.FacetGrid(tips, row='sex', col='time', margin_titles=True)
g.map(plt.hist, 'total_bill');

# %%
# Ящик с усами по признакам
def myFancyBoxplot(x, *args, **kwargs):
    return plt.boxplot(x.ravel())

g = sns.FacetGrid(tips, row='sex', col='time', margin_titles=True)
g.map(myFancyBoxplot, 'total_bill');
# Out:
# <ipython-input-48-9cd41e803e2a>:3: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   return plt.boxplot(x.ravel())
# <ipython-input-48-9cd41e803e2a>:3: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   return plt.boxplot(x.ravel())
# <ipython-input-48-9cd41e803e2a>:3: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   return plt.boxplot(x.ravel())
# <ipython-input-48-9cd41e803e2a>:3: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   return plt.boxplot(x.ravel())

# %% [markdown]
# ---

# %%
# Парные диаграммы
f, axs = plt.subplots(1, 2, figsize=(20, 8))
sns.boxplot(x="day", y="total_bill", hue="sex", data=tips, ax=axs[0]);
sns.violinplot(x="day", y="total_bill", hue="sex", data=tips, split=True, inner="quart", ax=axs[1]);

# %%
# Диаграмма рассеяния
sns.pairplot(tips, hue='sex');

# %% [markdown]
# ## Задание

# %%
# Набор данных о покемонах
df = pd.read_csv('https://raw.githubusercontent.com/yakushinav/omo/main/data/pokemon_full.csv')
df.drop('Number', axis=1, inplace=True)

# %%
print(df.shape)

df.head()
# Out:
# (721, 22)
#          Name Type_1  Type_2  Total  HP  Attack  Defense  Sp_Atk  Sp_Def  \
# 0   Bulbasaur  Grass  Poison    318  45      49       49      65      65
# 1     Ivysaur  Grass  Poison    405  60      62       63      80      80
# 2    Venusaur  Grass  Poison    525  80      82       83     100     100
# 3  Charmander   Fire     NaN    309  39      52       43      60      50
# 4  Charmeleon   Fire     NaN    405  58      64       58      80      65
#
#    Speed  ...  Color  hasGender Pr_Male  Egg_Group_1  Egg_Group_2  \
# 0     45  ...  Green       True   0.875      Monster        Grass
# 1     60  ...  Green       True   0.875      Monster        Grass
# 2     80  ...  Green       True   0.875      Monster        Grass
# 3     65  ...    Red       True   0.875      Monster       Dragon
# 4     80  ...    Red       True   0.875      Monster       Dragon
#
#   hasMegaEvolution Height_m  Weight_kg  Catch_Rate      Body_Style
# 0            False     0.71        6.9          45       quadruped
# 1            False     0.99       13.0          45       quadruped
# 2             True     2.01      100.0          45       quadruped
# 3            False     0.61        8.5          45  bipedal_tailed
# 4            False     1.09       19.0          45  bipedal_tailed
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Задание 1
# Нужно построить 4 гистограммы (histogram) на 30 карманов (бинов) главных 4 характеристик покемонов:
# - HP - здоровья
# - Attack - уровня атаки
# - Defense - уровня защиты
# - Speed - скорости
# Построить их надо на одном графике с 4 подграфиками (axes). Нужно использовать параметр figsize.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

url = 'https://raw.githubusercontent.com/yakushinav/omo/main/data/pokemon_full.csv'
df = pd.read_csv(url)

hp = df ['HP']
attack = df ['Attack']
defense = df ['Defense']
speed = df ['Speed']

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots (2, 2, figsize=(12,8))

ax1.hist(hp, bins=30, edgecolor='black', label='HP')
ax2.hist(attack, bins=30, edgecolor='black', label='Attack')
ax3.hist(defense, bins=30, edgecolor='black', label='Defense')
ax4.hist (speed, bins=30, edgecolor='black', label='Speed')

ax1.set_title('Histogram of HP')
ax1.set_xlabel('HP')
ax1.set_ylabel('Frequency')
ax1.legend()

ax2.set_title('Histogram of Attack')
ax2.set_xlabel('Attack')
ax2.set_ylabel('Frequency')
ax2.legend()

ax3.set_title('Histogram of Defense')
ax3.set_xlabel('Defense')
ax3.set_ylabel('Frequency')
ax3.legend()

ax4.set_title('Histogram of Speed')
ax4.set_xlabel('Speed')
ax4.set_ylabel('Frequency')
ax4. legend()
plt.tight_layout()

plt.show()

# %% [markdown]
# ## Задание 2
# Нужно выбрать несколько полей и построить диаграммы:
# - круговая
# - гистрограмма
# - график
# - ящик с усами
# - ViolinPlot

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

url = 'https://raw.githubusercontent.com/yakushinav/omo/main/data/pokemon_full.csv'
df = pd.read_csv(url)

selected_columns = ['Name', 'Type_1', 'Total', 'HP', 'Attack', 'Defense', 'Sp_Atk', 'Sp_Def', 'Speed']
df_selected = df[selected_columns]

labels = df_selected['Type_1'].value_counts().index
sizes = df_selected['Type_1'].value_counts().values
explode = (0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05)

fig1, ax1 = plt.subplots(figsize=(10, 6))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
shadow=True, startangle=140)
ax1.axis('equal')
plt.title("Распределение типов покемонов")
plt.show()

sns.histplot(df_selected['HP'], kde=False, bins=20)
plt.xlabel('Здоровье (HP)')
plt.ylabel('Количество покемонов')
plt.title('Распределение здоровья покемонов')
plt.show()

plt.figure(figsize=(10, 6))
plt.plot(df_selected['Name'], df_selected['Total'])
plt.xticks(rotation=90)
plt.xlabel('Имя покемона')
plt.ylabel('Общий показатель')
plt.title('Изменение общего показателя у покемонов')
plt.show()

sns.boxplot(x="Type_1", y="Total", data=df_selected)
plt.xticks(rotation=45)
plt.xlabel('Тип покемона')
plt.ylabel('Общий показатель')
plt.title('Ящик с усами для общего показателя по типу покемона')
plt.show()

sns.violinplot(x="Type_1", y="Total", data=df_selected)
plt.xticks(rotation=45)
plt.xlabel('Тип покемона')
plt.ylabel('Общий показатель')
plt.title('Violin Plot для общего показателя по типу покемона')
plt.show()

# %% [markdown]
# ## Задание 3
# Нужно построить диаграмму рассеяния

# %%
import pandas as pd
import matplotlib.pyplot as plt

url = 'https://raw.githubusercontent.com/yakushinav/omo/main/data/pokemon_full.csv'
df = pd.read_csv(url)
hp = df ['HP']
attack = df ['Attack']
plt.figure(figsize=(10, 6))
plt.scatter(hp, attack, c='blue', alpha=0.5)
plt.title('Диаграмма рассеяния HP vs Attack')
plt.xlabel('НР (Здоровье)')
plt.ylabel('Attack (Уровень атаки)')
plt.show()

# %% [markdown]
# ## Задание 4
# Нужно построить диаграмму распределения по полю Color

# %%
import pandas as pd
import matplotlib.pyplot as plt

url = 'https://raw.githubusercontent.com/yakushinav/omo/main/data/pokemon_full.csv'
df = pd.read_csv(url)

color_data = df['Color']

color_count = color_data.value_counts()

plt.figure(figsize=(10, 6))
plt.bar(color_count.index, color_count.values)
plt.xticks(rotation=45)
plt.xlabel('Цвет покемона')
plt.ylabel('Количество покемонов')
plt.title('Распределение покемонов по цвету')
plt.grid(axis='y')
plt.tight_layout()
plt.show()
